# %%
# 스택 :선입후출
# 예제 5-1.py

stack = []
stack.append(5)
stack.append(2)
stack.append(3)
stack.append(7)
stack.pop()
stack.append(1)
stack.append(4)
stack.pop()

print(stack)
print()
print(stack[::-1])
# Out:
# [5, 2, 3, 1]
#
# [1, 3, 2, 5]

# %%
# 큐: 선입선출

from collections import deque

queue=deque()

queue.append(5)
queue.append(2)
queue.append(3)
queue.append(7)
queue.popleft()
queue.append(1)
queue.append(4)
queue.popleft()

print(queue)
queue.reverse()
print(queue)
# Out:
# deque([3, 7, 1, 4])
# deque([4, 1, 7, 3])

# %%
# 재귀 함수
def rec_funct():
    print('재귀 함수')
    rec_funct()

rec_funct()
# Out:
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# 재귀 함수
# ...

# %%
# 위 코드는 종료하는 조건을 명시하지 않아 무한 호출
# 아래 코드는 종료 예제
def recursive_function(i):
    if i ==100:
        print(i,'번째 재귀 함수에서', i+1,'번째 재귀 함수를 호출한다')
        recursive_function(i+1)
        print(i,'번째 재귀 함수를 종료한다')
recursive_function(1)

# %%
#DFS:깊이 우선 탑색
